# %%
from pypdf import PdfReader, PdfWriter
import numpy as np

book1 = PdfReader(rf"C:\Users\NTres\OneDrive - Danmarks Tekniske Universitet\Bayesian_Machine_Learning\Reading\book1.pdf")
book2 = PdfReader(rf"C:\Users\NTres\OneDrive - Danmarks Tekniske Universitet\Bayesian_Machine_Learning\Reading\book2.pdf")

writer = PdfWriter()

book_to_use = book2
pages_to_keep = np.array([268,269,270])
pages_to_keep -= 1
for p in list(pages_to_keep):
    writer.add_page(book_to_use.pages[int(p)])

with open("5.2.pdf", "wb") as f:
    writer.write(f)
